# %%
# %%writefile hello_world.cu
# #include <stdio.h>
# #include <cuda_runtime.h>
#
# __global__ void hello_cuda ()
# {
#   printf ("hello cuda World THREAD  %d\n", threadIdx.x);
# }
#
# int main()
# {
#   hello_cuda<<<1,5>>>();
#   cudaDeviceSynchronize();
#   }
# Out:
# Overwriting hello_world.cu

# %%
# !nvcc hello_world.cu -o hello_world
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./hello_world
# Out:
# hello cuda World THREAD  0
# hello cuda World THREAD  1
# hello cuda World THREAD  2
# hello cuda World THREAD  3
# hello cuda World THREAD  4
